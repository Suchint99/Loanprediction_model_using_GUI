# %%
import pandas as pd
from tkinter import *
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle

# %%
df=pd.read_csv('train.csv')
X=df.drop(['Loan_Status','Loan_ID'], axis=1)
y=df['Loan_Status']
X['Gender'].fillna("Male", inplace=True)
X['Married'].fillna("Yes", inplace=True)
X['Dependents'].fillna(0,inplace=True)
X['Self_Employed'].fillna('No',inplace=True)
mean_loan=X['LoanAmount'].mean()
X['LoanAmount'].fillna(mean_loan,inplace=True)
X['Loan_Amount_Term'].fillna(X['Loan_Amount_Term'].mean(),inplace=True)
X['Credit_History'].fillna(X['Credit_History'].mean(),inplace=True)
X=pd.get_dummies(X)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.30)
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X,y)
#------------------Saving the Model----------------------------------
with open('Loan_Model','wb') as f:
    pickle.dump(model,f)
# Out:
# C:\Users\astha\AppData\Local\Temp\ipykernel_23584\3641796249.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['Gender'].fillna("Male", inplace=True)
# C:\Users\astha\AppData\Local\Temp\ipykernel_23584\3641796249.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
# ...

# %%
#-------------------------Importing required Libraries----------------------------------------
import pandas as pd
from tkinter import *
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from tkinter import messagebox
from tkinter import ttk
import pickle
import numpy as np

#---------------------------Creating window and its components-------------------------------------
window4 = Tk()
window4.title("Home Loan Prediction Form")
window4.geometry('1400x800')

genderlabel = Label(window4, text="Select Gender",font=("Arial Bold", 10))
gendercombo = ttk.Combobox(state="readonly",values=["--Select Gender--","Male","Female"])
gendercombo.current(0)

marriedlabel = Label(window4, text="Select Marital Status",font=("Arial Bold", 10))
marriedcombo = ttk.Combobox(state="readonly",values=["--Select Marital Status--","Yes","No"])
marriedcombo.current(0)

dependentlabel = Label(window4, text="Enter dependent",font=("Arial Bold", 10))
dependenttxt = Entry(window4,width=30,font=("Arial Bold", 10))

educationlabel = Label(window4, text="Select Education",font=("Arial Bold", 10))
educationcombo = ttk.Combobox(state="readonly",values=["--Select Education--","Graduate","Not Graduate"])
educationcombo.current(0)

selfemployedlabel = Label(window4, text="select self employed",font=("Arial Bold", 10))
selfemployedcombo = ttk.Combobox(state="readonly",values=["--Select Self employed--","Yes","No"])
selfemployedcombo.current(0)

Applicantincomelabel = Label(window4, text="Enter Applicant Income",font=("Arial Bold", 10))
Applicantincometxt = Entry(window4,width=30,font=("Arial Bold", 10))
    
Coapplicantincomelabel = Label(window4, text="Enter Co-Applicant Income",font=("Arial Bold", 10))
Coapplicantincometxt = Entry(window4,width=30,font=("Arial Bold", 10)) 
    

    
loanamountlabel = Label(window4, text="Enter Loan Amount",font=("Arial Bold", 10))
loanamounttxt = Entry(window4,width=30,font=("Arial Bold", 10)) 

loanamounttermlabel = Label(window4, text="Enter Loan Amount Term",font=("Arial Bold", 10))
loanamounttermtxt = Entry(window4,width=30,font=("Arial Bold", 10)) 

credithistorylabel = Label(window4, text="Enter Credit History",font=("Arial Bold", 10))
credithistorytxt = Entry(window4,width=30,font=("Arial Bold", 10)) 

propertyarealabel = Label(window4, text="Select Property Area",font=("Arial Bold", 10))

propertyareacombo = ttk.Combobox(state="readonly",values=["--Select Property Area--","Urban","Rural","Semiurban"])
propertyareacombo.current(0) 


pp = Label(window4, text="-",font=("Arial Bold", 10))

#------------------Setting position of the Components--------------------------------------
   
genderlabel.grid(column=1, row=0,pady= 10)
gendercombo.grid(column=2, row=0,pady= 10)

marriedlabel.grid(column=1, row=1,pady= 10)
marriedcombo.grid(column=2, row=1,pady= 10)
    
dependentlabel.grid(column=1, row=2,pady= 10)
dependenttxt.grid(column=2, row=2,pady= 10)
    
educationlabel.grid(column=1, row=3,pady= 10)
educationcombo.grid(column=2, row=3,pady= 10)
    
selfemployedlabel.grid(column=1, row=4,pady= 10)
selfemployedcombo.grid(column=2, row=4,pady= 10)
    
Applicantincomelabel.grid(column=1, row=5,pady= 10)
Applicantincometxt.grid(column=2, row=5,pady= 10)

Coapplicantincomelabel.grid(column=1, row=6,pady= 10)
Coapplicantincometxt.grid(column=2, row=6,pady= 10)

loanamountlabel.grid(column=1, row=7,pady= 10)
loanamounttxt.grid(column=2, row=7,pady= 10)

loanamounttermlabel.grid(column=1, row=8,pady= 10)
loanamounttermtxt.grid(column=2, row=8,pady= 10)

credithistorylabel.grid(column=1, row=9,pady= 10)
credithistorytxt.grid(column=2, row=9,pady= 10)

propertyarealabel.grid(column=1, row=10,pady= 10)
propertyareacombo.grid(column=2, row=10,pady= 10)
#------------------Loading Preprocessing and Creating the Model----------------------------------
with open('Loan_Model','rb')as f:
    model = pickle.load(f)
#----------------------------------------------------------------------------------------
def predict():
    gender=gendercombo.get()
    married=marriedcombo.get()
    dependents=int(dependenttxt.get())
    Education=educationcombo.get()
    SelfEmployed=selfemployedcombo.get()
    Applicantincome=int(Applicantincometxt.get())
    coapplicantincome=int(Coapplicantincometxt.get())
    loanamount=int(loanamounttxt.get())
    loanamountterm=int(loanamounttermtxt.get())
    credithistory=int(credithistorytxt.get())
    propertyarea=propertyareacombo.get()
    data = [[gender,married,dependents,Education,SelfEmployed,Applicantincome,coapplicantincome,loanamount,loanamountterm,credithistory,propertyarea]]
    newdf = pd.DataFrame(data, columns = ['Gender','Married','Dependents','Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area'])
   
    l1=['Dependents','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Gender_Female','Gender_Male','Married_No','Married_Yes','Education_Graduate','Education_Not Graduate','Self_Employed_No','Self_Employed_Yes','Property_Area_Rural','Property_Area_Semiurban','Property_Area_Urban']
    X_train = pd.DataFrame(0,index=np.arange(1) ,columns=l1)
    X_train
    missing_cols = set( X_train.columns ) - set( newdf.columns )
    missing_cols
    for c in missing_cols:
        newdf[c] = 0
    newdf = newdf[X_train.columns]
    yp=model.predict(newdf)
    print(yp)
    if (yp[0]=='Y'):
        pp.config(text = 'Your Loan is approved, Please contact at HDFC Bank Any Branch for further processing')
        pp.config(bg= "white", fg= "green")
        
    else:
        pp.config(text = 'Sorry ! Your Loan is not approved')
        pp.config(bg= "white", fg= "red")
   
predict = Button(window4, text="Predict Loan Status",font=("Arial Bold", 10),command=predict)
predict.grid(column=2, row=11)
pp.grid(column=2,row=12)
window4.mainloop()
# Out:
# ['N']
